# %%
import pandas as pd

df = pd.read_excel('../raw_data/OIL EXTRACTION RATE FOR CRUDE PALM OIL FOR THE MONTH OF JAN-DEC 2023.xlsx')
print(df.head())
# Out:
#   OIL EXTRACTION RATE FOR CRUDE PALM OIL FOR THE MONTH OF DECEMBER 2023  \
# 0                          JANUARY-JUNE 2022&2023(%)
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                              JOHOR
#
#   Unnamed: 1  Unnamed: 2 Unnamed: 3  Unnamed: 4 Unnamed: 5  Unnamed: 6  \
# 0        NaN         NaN        NaN         NaN        NaN         NaN
# 1        NaN         NaN        NaN         NaN        NaN         NaN
# 2        Jan         NaN        Feb         NaN        Mar         NaN
# 3       2022     2023.00       2022     2023.00       2022      2023.0
# 4      19.82       19.68      19.52       18.83      19.68        18.9
#
#   Unnamed: 7  Unnamed: 8 Unnamed: 9  Unnamed: 10 Unnamed: 11  Unnamed: 12  \
# 0        NaN         NaN        NaN          NaN         NaN          NaN
# ...
